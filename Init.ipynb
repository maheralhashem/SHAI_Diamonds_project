# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pycaret in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: xgboost in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numba>=0.55.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.59.1)
# Requirement already satisfied: yellowbrick>=1.4 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.5)
# Requirement already satisfied: requests>=2.27.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: jinja2>=1.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: pyod>=1.0.8 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: schemdraw==0.15 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.15)
# Requirement already satisfied: ipython>=5.5.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: scipy<2.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: psutil>=5.9.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (5.9.3)
# Requirement already satisfied: joblib>=1.2.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: tbats>=1.1.3 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (5.7.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: plotly>=5.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (5.20.0)
# Requirement already satisfied: kaleido>=0.2.1 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: xxhash in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.3.5)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.10.0)
# Collecting markupsafe>=2.0.1
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: ipywidgets>=7.6.5 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.30.1)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.12.3)
# Requirement already satisfied: wurlitzer in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (0.14.2)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: numpy<1.24,>=1.21 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: category-encoders>=2.4.0 in /root/venv/lib/python3.10/site-packages (from pycaret->-r ./requirements.txt (line 1)) (2.6.3)
# Requirement already satisfied: patsy>=0.5.1 in /root/venv/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret->-r ./requirements.txt (line 1)) (0.5.6)
# Requirement already satisfied: packaging in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from deprecation>=2.1.0->pycaret->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from imbalanced-learn>=0.8.1->pycaret->-r ./requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /root/venv/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret->-r ./requirements.txt (line 1)) (3.19.2)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: decorator in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: backcall in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (3.0.31)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: stack-data in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: comm>=0.1.3 in /root/venv/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /root/venv/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r ./requirements.txt (line 1)) (3.0.11)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /root/venv/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret->-r ./requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/site-packages (from lightgbm>=3.0.0->pycaret->-r ./requirements.txt (line 1)) (0.40.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (4.11.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /root/venv/lib/python3.10/site-packages (from numba>=0.55.0->pycaret->-r ./requirements.txt (line 1)) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pandas<2.0.0,>=1.3.0->pycaret->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from plotly>=5.0.0->pycaret->-r ./requirements.txt (line 1)) (8.1.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /root/venv/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (3.10.3)
# Requirement already satisfied: dash>=2.9.0 in /root/venv/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in /root/venv/lib/python3.10/site-packages (from plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: urllib3 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /root/venv/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r ./requirements.txt (line 1)) (3.0.10)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /root/venv/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret->-r ./requirements.txt (line 1)) (65.5.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.27.1->pycaret->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: scikit-base<0.9.0,>=0.6.1 in /root/venv/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret->-r ./requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (1.5.6)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: dash-core-components==2.0.0 in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: Werkzeug<3.1 in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: dash-table==5.0.0 in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: retrying in /root/venv/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (1.3.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: executing in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (2.0.8)
# Requirement already satisfied: pure-eval in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: blinker>=1.6.2 in /root/venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /root/venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret->-r ./requirements.txt (line 1)) (8.1.3)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.10/py-core/lib/python3.10/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
# Successfully installed markupsafe-2.1.5
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ab417452-7889-4cb1-949d-02a1a91d883b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
